# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
os.chdir("/Users/shree/Desktop/PROJECT")

# %%
os.listdir()
# Out:
# ['B.xlsx',
#  'GROUP 3_DEP PROJECT (015020, 015023, 015034, 015039, 015050).ipynb',
#  'Untitled.ipynb',
#  'data.csv',
#  '14 -HRAnalytics.xls',
#  'untitled1',
#  'comma-separated values-66143730AB82-1.csv',
#  '.ipynb_checkpoints',
#  '6-PS4_GamesSales.xls',
#  'untitled']

# %%
df=pd.read_csv("14 -HRAnalytics.xls")

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 4405   42        No  Travel_Rarely  Research & Development                 5
# 4406   29        No  Travel_Rarely  Research & Development                 2
# 4407   25        No  Travel_Rarely  Research & Development                25
# 4408   42        No  Travel_Rarely                   Sales                18
# 4409   40        No  Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 4405          4        Medical              1        4406  Female  ...
# 4406          4        Medical              1        4407    Male  ...
# 4407          2  Life Sciences              1        4408    Male  ...
# 4408          2        Medical              1        4409    Male  ...
# 4409          3        Medical              1        4410    Male  ...
#
#       NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
len(df.columns)
# Out:
# 24

# %%
A=df.values

# %%
A
# Out:
# array([[51, 'No', 'Travel_Rarely', ..., 1, 0, 0],
#        [31, 'Yes', 'Travel_Frequently', ..., 5, 1, 4],
#        [32, 'No', 'Travel_Frequently', ..., 5, 0, 3],
#        ...,
#        [25, 'No', 'Travel_Rarely', ..., 4, 1, 2],
#        [42, 'No', 'Travel_Rarely', ..., 9, 7, 8],
#        [40, 'No', 'Travel_Rarely', ..., 21, 3, 9]], dtype=object)

# %%
df.BusinessTravel
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2       Travel_Frequently
# 3              Non-Travel
# 4           Travel_Rarely
#               ...
# 4405        Travel_Rarely
# 4406        Travel_Rarely
# 4407        Travel_Rarely
# 4408        Travel_Rarely
# 4409        Travel_Rarely
# Name: BusinessTravel, Length: 4410, dtype: object

# %%
#Display 10 values of Business Travel
df.BusinessTravel[:10]
# Out:
# 0        Travel_Rarely
# 1    Travel_Frequently
# 2    Travel_Frequently
# 3           Non-Travel
# 4        Travel_Rarely
# 5        Travel_Rarely
# 6        Travel_Rarely
# 7        Travel_Rarely
# 8        Travel_Rarely
# 9           Non-Travel
# Name: BusinessTravel, dtype: object

# %%
df[['Age','BusinessTravel']]
# Out:
#       Age     BusinessTravel
# 0      51      Travel_Rarely
# 1      31  Travel_Frequently
# 2      32  Travel_Frequently
# 3      38         Non-Travel
# 4      32      Travel_Rarely
# ...   ...                ...
# 4405   42      Travel_Rarely
# 4406   29      Travel_Rarely
# 4407   25      Travel_Rarely
# 4408   42      Travel_Rarely
# 4409   40      Travel_Rarely
#
# [4410 rows x 2 columns]

# %%
df['Age'].unique()
# Out:
# array([51, 31, 32, 38, 46, 28, 29, 25, 45, 36, 55, 47, 37, 21, 35, 26, 50,
#        53, 42, 44, 49, 18, 41, 39, 58, 33, 43, 52, 27, 30, 54, 40, 23, 48,
#        57, 34, 24, 22, 56, 60, 19, 20, 59])

# %%
abc=df.select_dtypes(include=['int64']).columns

# %%
abc
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeID',
#        'JobLevel', 'MonthlyIncome', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
efg=df.select_dtypes(include=['object']).columns

# %%
efg
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18'],
#       dtype='object')

# %%
df['Age'].memory_usage()
# Out:
# 35408

# %%
df.Age.values
# Out:
# array([51, 31, 32, ..., 25, 42, 40])

# %%
df.groupby("Age")['YearsAtCompany'].mean()
# Out:
# Age
# 18     0.000000
# 19     0.777778
# 20     1.545455
# 21     1.846154
# 22     2.062500
# 23     2.642857
# 24     3.346154
# 25     3.846154
# 26     4.692308
# 27     5.020833
# 28     4.375000
# 29     5.602941
# 30     6.516667
# 31     5.681159
# 32     6.131148
# 33     6.586207
# 34     7.064935
# 35     6.794872
# 36     7.405797
# 37     6.380000
# 38     6.534483
# 39     9.761905
# 40     8.438596
# 41     9.700000
# 42     8.326087
# 43     8.281250
# 44     8.272727
# 45     9.365854
# 46     8.939394
# 47    10.041667
# 48     6.421053
# 49     8.416667
# 50    10.800000
# 51    10.052632
# 52    12.444444
# 53     9.736842
# 54     7.333333
# 55    11.909091
# 56     6.857143
# 57     5.250000
# 58    11.571429
# 59     5.800000
# 60    12.200000
# Name: YearsAtCompany, dtype: float64

# %%
df.groupby(["Age","BusinessTravel"])['YearsAtCompany'].mean()
# Out:
# Age  BusinessTravel
# 18   Non-Travel            0.000
#      Travel_Frequently     0.000
#      Travel_Rarely         0.000
# 19   Non-Travel            1.000
#      Travel_Frequently     0.000
#                            ...
# 59   Non-Travel            3.000
#      Travel_Frequently     4.000
#      Travel_Rarely         6.375
# 60   Travel_Frequently    18.000
#      Travel_Rarely        10.750
# Name: YearsAtCompany, Length: 123, dtype: float64

# %%
df.groupby("Age")["YearsAtCompany"].mean().reset_index()
# Out:
#     Age  YearsAtCompany
# 0    18        0.000000
# 1    19        0.777778
# 2    20        1.545455
# 3    21        1.846154
# 4    22        2.062500
# 5    23        2.642857
# 6    24        3.346154
# 7    25        3.846154
# 8    26        4.692308
# 9    27        5.020833
# 10   28        4.375000
# 11   29        5.602941
# 12   30        6.516667
# 13   31        5.681159
# 14   32        6.131148
# 15   33        6.586207
# 16   34        7.064935
# 17   35        6.794872
# 18   36        7.405797
# 19   37        6.380000
# 20   38        6.534483
# 21   39        9.761905
# 22   40        8.438596
# 23   41        9.700000
# 24   42        8.326087
# 25   43        8.281250
# 26   44        8.272727
# 27   45        9.365854
# 28   46        8.939394
# 29   47       10.041667
# 30   48        6.421053
# 31   49        8.416667
# 32   50       10.800000
# 33   51       10.052632
# 34   52       12.444444
# 35   53        9.736842
# 36   54        7.333333
# ...

# %%
df1=df.groupby("Age")["YearsAtCompany"].mean().reset_index()

# %%
df2=df.groupby(["Age","BusinessTravel"])['YearsAtCompany'].mean().reset_index()

# %%
df3= df1.merge(df2, on='Age', how='outer')

# %%
df3
# Out:
#      Age  YearsAtCompany_x     BusinessTravel  YearsAtCompany_y
# 0     18          0.000000         Non-Travel             0.000
# 1     18          0.000000  Travel_Frequently             0.000
# 2     18          0.000000      Travel_Rarely             0.000
# 3     19          0.777778         Non-Travel             1.000
# 4     19          0.777778  Travel_Frequently             0.000
# ..   ...               ...                ...               ...
# 118   59          5.800000         Non-Travel             3.000
# 119   59          5.800000  Travel_Frequently             4.000
# 120   59          5.800000      Travel_Rarely             6.375
# 121   60         12.200000  Travel_Frequently            18.000
# 122   60         12.200000      Travel_Rarely            10.750
#
# [123 rows x 4 columns]

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df3.drop('BusinessTravel',inplace=True,axis=1)

# %%
df3
# Out:
#      Age  YearsAtCompany_x  YearsAtCompany_y
# 0     18          0.000000             0.000
# 1     18          0.000000             0.000
# 2     18          0.000000             0.000
# 3     19          0.777778             1.000
# 4     19          0.777778             0.000
# ..   ...               ...               ...
# 118   59          5.800000             3.000
# 119   59          5.800000             4.000
# 120   59          5.800000             6.375
# 121   60         12.200000            18.000
# 122   60         12.200000            10.750
#
# [123 rows x 3 columns]

# %%
BTravel=pd.get_dummies(df.BusinessTravel)

# %%
df3=pd.concat([df3,BTravel])

# %%
df.NumCompaniesWorked.isnull().sum()
# Out:
# 19

# %%
df.NumCompaniesWorked.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Name: NumCompaniesWorked, Length: 4410, dtype: bool

# %%
df3
# Out:
#        Age  YearsAtCompany_x  YearsAtCompany_y  Non-Travel  Travel_Frequently  \
# 0     18.0          0.000000               0.0         NaN                NaN
# 1     18.0          0.000000               0.0         NaN                NaN
# 2     18.0          0.000000               0.0         NaN                NaN
# 3     19.0          0.777778               1.0         NaN                NaN
# 4     19.0          0.777778               0.0         NaN                NaN
# ...    ...               ...               ...         ...                ...
# 4405   NaN               NaN               NaN         0.0                0.0
# 4406   NaN               NaN               NaN         0.0                0.0
# 4407   NaN               NaN               NaN         0.0                0.0
# 4408   NaN               NaN               NaN         0.0                0.0
# 4409   NaN               NaN               NaN         0.0                0.0
#
#       Travel_Rarely
# ...

# %%
BTravel
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0              0                  0              1
# 1              0                  1              0
# 2              0                  1              0
# 3              1                  0              0
# 4              0                  0              1
# ...          ...                ...            ...
# 4405           0                  0              1
# 4406           0                  0              1
# 4407           0                  0              1
# 4408           0                  0              1
# 4409           0                  0              1
#
# [4410 rows x 3 columns]

# %%
df3
# Out:
#        Age  YearsAtCompany_x  YearsAtCompany_y  Non-Travel  Travel_Frequently  \
# 0     18.0          0.000000               0.0         NaN                NaN
# 1     18.0          0.000000               0.0         NaN                NaN
# 2     18.0          0.000000               0.0         NaN                NaN
# 3     19.0          0.777778               1.0         NaN                NaN
# 4     19.0          0.777778               0.0         NaN                NaN
# ...    ...               ...               ...         ...                ...
# 4405   NaN               NaN               NaN         0.0                0.0
# 4406   NaN               NaN               NaN         0.0                0.0
# 4407   NaN               NaN               NaN         0.0                0.0
# 4408   NaN               NaN               NaN         0.0                0.0
# 4409   NaN               NaN               NaN         0.0                0.0
#
#       Travel_Rarely
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df['Education'].value_counts()
# Out:
# 3    1716
# 4    1194
# 2     846
# 1     510
# 5     144
# Name: Education, dtype: int64

# %%
Education = pd.DataFrame(df['Education'].value_counts())
Education = Education.reset_index()
Education.columns = ['Education', 'No. of employees']

# %%
Education
# Out:
#    Education  No. of employees
# 0          3              1716
# 1          4              1194
# 2          2               846
# 3          1               510
# 4          5               144

# %%
#Education level and the no.of employees count level
sns.countplot(x="Education",data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
#No.of Attirition 
sns.countplot(x="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#No.of male and Female employees 
sns.countplot(x="Gender",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#No.of Employees for different Business Travel rate
sns.countplot(x="BusinessTravel",data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
df.Department.values
# Out:
# array(['Sales', 'Research & Development', 'Research & Development', ...,
#        'Research & Development', 'Sales', 'Research & Development'],
#       dtype=object)

# %%
#Different Age category
df['Age_cat']=pd.cut(df.Age,bins=3,labels=['y','m','s'])

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
sns.countplot(x="Age_cat",data=df)
# Out:
# <AxesSubplot:xlabel='Age_cat', ylabel='count'>

# %%
sns.catplot(x="Attrition",col="Age_cat",kind="count",data=df)

# %%
sns.catplot(x="Attrition",col="BusinessTravel",kind="count",data=df)

# %%
sns.catplot(x="BusinessTravel",hue="Age_cat",col="Gender",kind="count",data=df)

# %%
ax=sns.displot(df.Age)
ax.set(xlim=(18,60),xlabel='Age of Persons',ylabel='Count',title='Histogram of Age',xticks=list(range(18,70,10)))

# %%
sns.displot(df['TotalWorkingYears'])

# %%
sns.boxplot(x='Education',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Age'>

# %%
sns.boxplot(x='EducationField',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Age'>

# %%
sns.jointplot(df['EducationField'],df.Age)
# Out:
# /Users/shree/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df['PercentSalaryHike'],df['Age'])
# Out:
# /Users/shree/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,8))
grouped=df.groupby(['Age_cat','NumCompaniesWorked'])
data_when=grouped['YearsAtCompany'].sum().unstack()
sns.heatmap(data_when)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Age_cat'>

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'Age_cat'],
#       dtype='object')

# %%
df.MonthlyIncome
# Out:
# 0       131160
# 1        41890
# 2       193280
# 3        83210
# 4        23420
#          ...
# 4405     60290
# 4406     26790
# 4407     37020
# 4408     23980
# 4409     54680
# Name: MonthlyIncome, Length: 4410, dtype: int64

# %%
Avg_Salary=df.MonthlyIncome.mean()

# %%
Avg_Salary
# Out:
# 65029.31292517007

# %%
#At each Age category, their monthly income at their Job Role
sns.relplot(x='Age_cat',y='JobRole',hue='MonthlyIncome',kind='scatter',cmap='winter',data=df)

# %%
#At each Age category, their monthly income at their job level
sns.relplot(x='Age_cat',y='JobLevel',hue='MonthlyIncome',kind='scatter',cmap='winter',data=df)

# %%
#Job level in relation to the Salary Hike
plt.figure(figsize=(15,5))
sns.barplot(x=df['JobRole'], y=df['PercentSalaryHike'])
plt.xticks(rotation= 90)
plt.xlabel('Position')
plt.ylabel('Salary Hike in %')
plt.title('Job level in relation to the Salary Hike')
plt.show()

# %%
df["JobLevel"].values
# Out:
# array([1, 1, 4, ..., 2, 1, 2])
